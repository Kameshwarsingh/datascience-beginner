# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit

# %%
def my_func(x, a, b, c):
    return a * np.exp(-b * x) + c

# %%
xdata = np.linspace(0, 4, 50)
y = func(xdata, 2.5, 1.3, 0.5)
rng = np.random.default_rng()
y_noise = 0.2 * rng.normal(size=xdata.size)
ydata = y + y_noise

# %%
plt.plot(xdata, ydata, 'b-', label='data')

#1
popt, pcov = curve_fit(my_func, xdata, ydata)
plt.plot(xdata, func(xdata, *popt), 'r-',label='fit: a=%5.3f, b=%5.3f, c=%5.3f' % tuple(popt))

#2
popt, pcov = curve_fit(my_func, xdata, ydata, bounds=(0, [3., 1., 0.5]))
plt.plot(xdata, my_func(xdata, *popt), 'g--',label='fit: a=%5.3f, b=%5.3f, c=%5.3f' % tuple(popt))

plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.show()

# %%
np.linalg.cond(pcov)
# Out:
# 28.555026494109253

# %%
def func2(x, a, b, c, d):
    return a * d * np.exp(-b * x) + c  # a and d are redundant

popt, pcov = curve_fit(func2, xdata, ydata)
np.linalg.cond(pcov)
# Out:
# 8.610022810175124e+31

# %%
np.diag(pcov)
# Out:
# array([1.20428080e+29, 3.85871104e-02, 6.18883067e-03, 1.31109257e+28])
